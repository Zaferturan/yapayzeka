# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.1.0
# altair                       5.3.0
# anyio                        4.4.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# audioread                    3.0.1
# Babel                        2.15.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# blinker                      1.8.2
# cachetools                   5.4.0
# certifi                      2024.7.4
# cffi                         1.16.0
# charset-normalizer           3.3.2
# click                        8.1.7
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# ...
