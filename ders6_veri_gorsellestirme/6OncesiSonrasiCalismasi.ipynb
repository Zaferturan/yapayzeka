# %% [markdown]
# ## Öncesi sonrası image slider yapımı

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pip install leafmap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import leafmap.foliumap as leafmap
img1 = "Oncesi_Sonrası2.jpeg"
img2 = "Oncesi_Sonrası1.jpeg"
leafmap.image_comparison(
    img1,
    img2,
    label1="2024",
    label2="2019",
    starting_position=50,
    out_html="slider_comparison.html"
)
#Orman yangını 
#deprem bölgesi
#Öncesi sonrası yapmak için
# image_comparison.html dosyayı açıp kullanabilirsiniz.
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 376; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: '2024',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: '2019',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
#         </head>
# ...
